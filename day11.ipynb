# %%
import cv2
import matplotlib.pyplot as plt

# %%
vid = cv2.VideoCapture(0)

# %%
type(vid)
# Out:
# cv2.VideoCapture

# %%
vid.isOpened
# Out:
# <function VideoCapture.isOpened>

# %%
k=vid.read()

# %%
type(k),len(k)
# Out:
# (tuple, 2)

# %%
k
# Out:
# (True,
#  array([[[ 33,  24,  45],
#          [ 32,  23,  48],
#          [ 30,  24,  52],
#          ...,
#          [148, 148, 152],
#          [149, 148, 151],
#          [143, 143, 145]],
#
#         [[ 31,  25,  43],
#          [ 30,  24,  44],
#          [ 29,  24,  45],
#          ...,
#          [149, 149, 150],
#          [150, 150, 150],
#          [150, 150, 150]],
#
#         [[ 25,  24,  49],
#          [ 27,  24,  47],
#          [ 28,  23,  44],
#          ...,
#          [155, 154, 158],
#          [153, 153, 153],
#          [153, 153, 152]],
#
#         ...,
#
#         [[  8,   8,  10],
#          [  6,   6,   7],
#          [  5,   5,   5],
#          ...,
#          [ 20,  18,  32],
#          [ 19,  18,  32],
#          [ 19,  18,  32]],
#
#         [[  6,   6,   6],
#          [  6,   6,   6],
#          [  5,   5,   5],
#          ...,
#          [ 20,  18,  31],
#          [ 21,  18,  30],
#          [ 21,  18,  30]],
#
#         [[  6,   6,   6],
#          [  6,   6,   6],
#          [  5,   5,   5],
#          ...,
#          [ 20,  19,  29],
#          [ 21,  19,  26],
#          [ 21,  19,  26]]], dtype=uint8))

# %%
m,n=(3,4)

# %%
flag, img =vid.read()

# %%
if flag:
      plt.imshow(img[:,:,::-1])

# %%
img.shape
# Out:
# (480, 640, 3)

# %%
for i in range(100):
    flag, img =vid.read()
    if flag:
        plt.imshow(img[:,:,::-1])

# %%
vid.release()

# %%
fd=cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
vid=cv2.VideoCapture(0)
while True:
   flag, img =vid.read()
   if flag:
      #processing code
      img_gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
      faces=fd.detectMultiScale(img_gray,1.1,5)
      th, img_bw = cv2.threshold(img_gray,100,255,cv2.THRESH_BINARY_INV )
      x,y,w,h = (250,200,100,100)
      img_cropped = img[y:y+h,x:x+w,:]     

      cv2.rectangle(img, pt1=(x,y),pt2=(x+w,y+h), color=(0,0,255))
     
      cv2.imshow('preview',img)
      key =cv2.waitKey(1)
      if key==ord('q'):
        break
   else:
      print('NO FRAMES')
      break
cv2.destroyAllWindows()
cv2.waitKey(1)              
vid.release()
del vid
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\AMANGO~1\AppData\Local\Temp/ipykernel_17372/2007947617.py in <module>
# ----> 1 fd=cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
#       2 vid=cv2.VideoCapture(0)
#       3 while True:
#       4    flag, img =vid.read()
#       5    if flag:
#
# NameError: name 'cv2' is not defined
